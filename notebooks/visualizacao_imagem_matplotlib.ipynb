# %% [markdown]
# # Visualização de Imagens com Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# LENDO IMAGEM DO DISCO
image = plt.imread("./images/bahia.jpeg")

# %%
# Vendo o tipo de dado do objeto imagem e vendo os valores de cada pixel
print(type(image))
image[0,0]
# Out:
# <class 'numpy.ndarray'>
# array([  9, 172, 231], dtype=uint8)

# %%
# VISUALIZAR IMAGENS
plt.imshow(image)
